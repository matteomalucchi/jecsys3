# %%
import ROOT
# Out:
# Welcome to JupyROOT 6.26/10

# %%
root_name="/work/mmalucch/L2L3Res_inputs/mc_truth_below15_2022_pnetreg/zb/jme_bplusZ_merged_mc_truth_below15_2022_pnetreg_2022CD.root"
file=ROOT.TFile.Open(root_name)
# Out:
# Error in <TList::Clear>: A list is accessing an object (0x557110ddab50) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x557110ddaff0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x557110ddb3c0) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x557110ddb860) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x557110ddba90) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x557110e00160) already deleted (list name = TList)
# Error in <TList::Clear>: A list is accessing an object (0x557110e01080) already deleted (list name = TList)

# %%
p2jes=file.Get("data/eta_00_13/rmpfjet1_zmmjet_ctag_a100")
# p2jes=file.Get("mc/l2res/p2jes")
#draw
c=ROOT.TCanvas("c","c",1000,800)
p2jes.Draw()
c.Draw()
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c

# %%
file.ls("*")
# Out:
# TFile**		/work/mmalucch/L2L3Res_inputs/mc_truth_below15_2022_pnetreg/zb/jme_bplusZ_merged_mc_truth_below15_2022_pnetreg_2022CD.root
#  TFile*		/work/mmalucch/L2L3Res_inputs/mc_truth_below15_2022_pnetreg/zb/jme_bplusZ_merged_mc_truth_below15_2022_pnetreg_2022CD.root
#   TDirectoryFile*		mc	mc
#    TDirectoryFile*		l2res	l2res
#     OBJ: TProfile2D	p2jes	 : 0 at: 0x557111207b90
#     KEY: TH2D	h2ptetapf;1
#     KEY: TH2D	h2pteta;1
#     KEY: TH2D	h2ptetatc;1
#     KEY: TProfile2D	p2jes;1
#     KEY: TProfile2D	p2jsfpf;1
#     KEY: TProfile2D	p2jsf;1
#     KEY: TProfile2D	p2jsftc;1
#     KEY: TProfile2D	p2m0pf;1
#     KEY: TProfile2D	p2m0;1
#     KEY: TProfile2D	p2m0tc;1
#     KEY: TProfile2D	p2m0x;1
#     KEY: TProfile2D	p2m2pf;1
#     KEY: TProfile2D	p2m2;1
#     KEY: TProfile2D	p2m2tc;1
#     KEY: TProfile2D	p2m2x;1
#     KEY: TProfile2D	p2mnpf;1
#     KEY: TProfile2D	p2mn;1
#     KEY: TProfile2D	p2mntc;1
#     KEY: TProfile2D	p2mnu;1
#     KEY: TProfile2D	p2mnux;1
# ...

# %%
import uproot
from matplotlib import pyplot as plt

# %%
root_name="/work/mmalucch/L2L3Res_inputs/mc_truth_below15_2022_pnetreg/zb/jme_bplusZ_merged_mc_truth_below15_2022_pnetreg_2022CD.root"

file_uproot = uproot.open(root_name)
for key in file_uproot.keys():
    # if "mass" in key:
    print(key)
# Out:
# data;1
# data/chf_run_zpt110;1
# data/chf_run_zpt30;1
# data/chf_run_zpt60;1
# data/db_run_zpt110;1
# data/db_run_zpt30;1
# data/db_run_zpt60;1
# data/l2res;1
# data/l2res/h2ptetapf;1
# data/l2res/h2pteta;1
# data/l2res/h2ptetatc;1
# data/l2res/p2jes;1
# data/l2res/p2jsfpf;1
# data/l2res/p2jsf;1
# data/l2res/p2jsftc;1
# data/l2res/p2m0pf;1
# data/l2res/p2m0;1
# data/l2res/p2m0tc;1
# data/l2res/p2m0x;1
# data/l2res/p2m2pf;1
# data/l2res/p2m2;1
# data/l2res/p2m2tc;1
# data/l2res/p2m2x;1
# data/l2res/p2mnpf;1
# data/l2res/p2mn;1
# data/l2res/p2mntc;1
# data/l2res/p2mnu;1
# data/l2res/p2mnux;1
# data/l2res/p2mnx;1
# data/l2res/p2mupf;1
# data/l2res/p2mu;1
# data/l2res/p2mutc;1
# data/l2res/p2mux;1
# data/l2res/p2respf;1
# data/l2res/p2res;1
# data/l2res/p2restc;1
# data/l2res/p2r;1
# data/eta_00_13;1
# data/eta_00_13/h3D_Zpt_Mu_Mu_alpha100;1
# data/eta_00_13/h3D_Zpt_Mu_Mu_alpha30;1
# data/eta_00_13/h3D_Zpt_Mu_Mu_btag_alpha100;1
# data/eta_00_13/h3D_Zpt_Mu_Mu_btag_alpha30;1
# ...

# %%
histo = file_uproot["DYJetsToLL_M_50_Summer22BCD_weighted_counters"]
print(histo)
type(histo)
# Out:
# <TH1D (version 3) at 0x7fe89e371130>
# uproot.models.TH.Model_TH1D_v3

# %%
#plot histo
histo_numpy=histo.to_numpy()
plt.plot(histo_numpy[1][ :-1],histo_numpy[0])
plt.show()

# %%
histo_hist=histo.to_hist()
#plot hist
plt.plot(histo_hist.axes[0].centers,histo_hist.values())

# %%
histo2d = file_uproot["mc/l2res/h2ptetapf"]
histo2d_hist=histo2d.to_hist()
#plot hist 2d
plt.imshow(histo2d_hist.values().T, origin='lower', aspect='auto', extent=(histo2d_hist.axes[0].edges[0], histo2d_hist.axes[0].edges[-1], histo2d_hist.axes[1].edges[0], histo2d_hist.axes[1].edges[-1]))
#add colorbar
plt.colorbar()
